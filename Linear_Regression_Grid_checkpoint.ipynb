# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshu-09/AISECT-AIML/blob/main/Linear_Regression_Grid_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#used onehot code to encode the values
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Assigning independent and dependent values
x=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
y=dataset['charges']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %%
#using standardscaler to standardise the value
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# Only valid parameters for LinearRegression in sklearn >=1.0
param_grid = {
    'fit_intercept': [True, False],   # whether to include intercept
    'positive': [False, True]         # force coefficients >=0
}

grid = GridSearchCV(
    LinearRegression(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'fit_intercept': [True, False],
#                          'positive': [False, True]},
#              verbose=3)

# %%
from sklearn.model_selection import GridSearchCV

# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)

# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'fit_intercept': True, 'positive': True}
# r2: 0.7162273379118892

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       0.001775      0.000118         0.001082        0.000055
# 0       0.005799      0.006801         0.001364        0.000231
# 3       0.002576      0.001876         0.001948        0.001659
# 2       0.002926      0.001377         0.001977        0.001727
#
#    param_fit_intercept  param_positive  \
# 1                 True            True
# 0                 True           False
# 3                False            True
# 2                False           False
#
#                                         params  split0_test_score  \
# 1    {'fit_intercept': True, 'positive': True}           0.707268
# 0   {'fit_intercept': True, 'positive': False}           0.707268
# 3   {'fit_intercept': False, 'positive': True}          -0.858142
# 2  {'fit_intercept': False, 'positive': False}          -0.858142
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
#importing pickle to save the model
import pickle
filename = "LinearRegressor.sav"
pickle.dump(grid.best_estimator_, open(filename, 'wb'))

# %%
load_model=pickle.load(open("/content/LinearRegressor.sav","rb"))

# %%
#Getting input from user
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:50
# BMI:30.970
# Children:3
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[257363.66856637]
