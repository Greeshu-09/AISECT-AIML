# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshu-09/AISECT-AIML/blob/main/RandomForestRegressor_Grid_less_parameters_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Encoding the values using One hot coding
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#Assigning independent and dependent value
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'n_estimators': [50, 100],        # reasonable tree counts
    'criterion': ['squared_error'],   # default, reliable
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', None],
    'bootstrap': [True]
}

grid = GridSearchCV(
    RandomForestRegressor(random_state=42, n_jobs=-1),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)

grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True], 'criterion': ['squared_error'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['sqrt', None],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# r2: 0.8304076586781151

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23       0.467801      0.070218         0.045087        0.006528
# 39       0.557196      0.061542         0.077925        0.015663
# 7        0.335827      0.008442         0.038055        0.004032
# 22       0.247429      0.062650         0.042253        0.010427
# 21       0.370704      0.030334         0.044485        0.007609
# 38       0.384290      0.071490         0.062393        0.017699
# 6        0.166323      0.005896         0.026628        0.000790
# 20       0.191300      0.015102         0.028888        0.004813
# 4        0.173293      0.015698         0.025987        0.000404
# 36       0.200764      0.033824         0.039415        0.018579
# 5        0.342531      0.004090         0.039202        0.003650
# 37       0.666694      0.196139         0.086939        0.032054
# 31       0.667656      0.059651         0.079350        0.036115
# 19       0.408764      0.087884         0.052576        0.018238
# 18       0.183825      0.019641         0.027458        0.003029
# 29       0.543638      0.101252         0.049165        0.024180
# 15       1.158391      0.182610         0.095609        0.011059
# 47       0.745987      0.144816         0.078408        0.037592
# 34       0.229413      0.061137         0.040304        0.013926
# 2        0.336622      0.047254         0.046717        0.016914
# 35       0.600222      0.097048         0.076010        0.019717
# 3        0.544895      0.074749         0.054834        0.017027
# 30       0.296615      0.056876         0.033034        0.011377
# 17       0.431254      0.086301         0.049508        0.020728
# 13       0.440902      0.007041         0.040199        0.006800
# 45       0.662229      0.139257         0.087687        0.031244
# 28       0.319316      0.071404         0.039331        0.012415
# 14       0.216299      0.005347         0.030974        0.008787
# 46       0.484629      0.031255         0.080029        0.006485
# 16       0.373075      0.107674         0.043932        0.010481
# 44       0.232387      0.004664         0.034044        0.006398
# 12       0.224346      0.014930         0.028860        0.005091
# 27       0.879017      0.104187         0.075457        0.013811
# 1        0.516217      0.123111         0.057261        0.014335
# 26       0.330825      0.077767         0.031934        0.005900
# 33       0.411953      0.014834         0.054230        0.024821
# 11       0.497627      0.063957         0.049131        0.024417
# 43       0.484982      0.019002         0.048424        0.008407
# 0        0.213354      0.013047         0.027520        0.000550
# 32       0.259259      0.113724         0.028892        0.003610
# 10       0.231462      0.010463         0.028931        0.005370
# 42       0.233503      0.007247         0.030869        0.004801
# 25       0.566987      0.058628         0.064866        0.018573
# 24       0.297058      0.048449         0.035264        0.011131
# 41       0.573606      0.031571         0.050127        0.003547
# 9        0.532460      0.017583         0.041581        0.004904
# 8        0.272902      0.016756         0.026348        0.000373
# 40       0.320424      0.085492         0.027560        0.001989
#
#     param_bootstrap param_criterion param_max_depth param_max_features  \
# 23             True   squared_error              10               sqrt
# 39             True   squared_error              20               sqrt
# 7              True   squared_error            None               sqrt
# 22             True   squared_error              10               sqrt
# 21             True   squared_error              10               sqrt
# 38             True   squared_error              20               sqrt
# 6              True   squared_error            None               sqrt
# 20             True   squared_error              10               sqrt
# 4              True   squared_error            None               sqrt
# 36             True   squared_error              20               sqrt
# 5              True   squared_error            None               sqrt
# 37             True   squared_error              20               sqrt
# 31             True   squared_error              10               None
# 19             True   squared_error              10               sqrt
# 18             True   squared_error              10               sqrt
# 29             True   squared_error              10               None
# 15             True   squared_error            None               None
# 47             True   squared_error              20               None
# 34             True   squared_error              20               sqrt
# 2              True   squared_error            None               sqrt
# 35             True   squared_error              20               sqrt
# 3              True   squared_error            None               sqrt
# 30             True   squared_error              10               None
# 17             True   squared_error              10               sqrt
# 13             True   squared_error            None               None
# 45             True   squared_error              20               None
# 28             True   squared_error              10               None
# 14             True   squared_error            None               None
# 46             True   squared_error              20               None
# 16             True   squared_error              10               sqrt
# 44             True   squared_error              20               None
# 12             True   squared_error            None               None
# 27             True   squared_error              10               None
# 1              True   squared_error            None               sqrt
# 26             True   squared_error              10               None
# 33             True   squared_error              20               sqrt
# 11             True   squared_error            None               None
# 43             True   squared_error              20               None
# 0              True   squared_error            None               sqrt
# 32             True   squared_error              20               sqrt
# 10             True   squared_error            None               None
# 42             True   squared_error              20               None
# 25             True   squared_error              10               None
# 24             True   squared_error              10               None
# 41             True   squared_error              20               None
# 9              True   squared_error            None               None
# 8              True   squared_error            None               None
# 40             True   squared_error              20               None
#
#     param_min_samples_leaf  param_min_samples_split  param_n_estimators  \
# 23                       2                        5                 100
# 39                       2                        5                 100
# 7                        2                        5                 100
# 22                       2                        5                  50
# 21                       2                        2                 100
# 38                       2                        5                  50
# 6                        2                        5                  50
# 20                       2                        2                  50
# 4                        2                        2                  50
# 36                       2                        2                  50
# 5                        2                        2                 100
# 37                       2                        2                 100
# 31                       2                        5                 100
# 19                       1                        5                 100
# 18                       1                        5                  50
# 29                       2                        2                 100
# 15                       2                        5                 100
# 47                       2                        5                 100
# 34                       1                        5                  50
# 2                        1                        5                  50
# 35                       1                        5                 100
# 3                        1                        5                 100
# 30                       2                        5                  50
# 17                       1                        2                 100
# 13                       2                        2                 100
# 45                       2                        2                 100
# 28                       2                        2                  50
# 14                       2                        5                  50
# 46                       2                        5                  50
# 16                       1                        2                  50
# 44                       2                        2                  50
# 12                       2                        2                  50
# 27                       1                        5                 100
# 1                        1                        2                 100
# 26                       1                        5                  50
# 33                       1                        2                 100
# 11                       1                        5                 100
# 43                       1                        5                 100
# 0                        1                        2                  50
# 32                       1                        2                  50
# 10                       1                        5                  50
# 42                       1                        5                  50
# 25                       1                        2                 100
# 24                       1                        2                  50
# 41                       1                        2                 100
# 9                        1                        2                 100
# 8                        1                        2                  50
# 40                       1                        2                  50
#
#                                                params  split0_test_score  \
# 23  {'bootstrap': True, 'criterion': 'squared_erro...           0.859064
# 39  {'bootstrap': True, 'criterion': 'squared_erro...           0.861384
# 7   {'bootstrap': True, 'criterion': 'squared_erro...           0.861229
# 22  {'bootstrap': True, 'criterion': 'squared_erro...           0.860174
# 21  {'bootstrap': True, 'criterion': 'squared_erro...           0.859263
# 38  {'bootstrap': True, 'criterion': 'squared_erro...           0.858579
# 6   {'bootstrap': True, 'criterion': 'squared_erro...           0.858253
# 20  {'bootstrap': True, 'criterion': 'squared_erro...           0.860247
# 4   {'bootstrap': True, 'criterion': 'squared_erro...           0.861900
# 36  {'bootstrap': True, 'criterion': 'squared_erro...           0.861900
# 5   {'bootstrap': True, 'criterion': 'squared_erro...           0.859501
# 37  {'bootstrap': True, 'criterion': 'squared_erro...           0.859501
# 31  {'bootstrap': True, 'criterion': 'squared_erro...           0.864793
# 19  {'bootstrap': True, 'criterion': 'squared_erro...           0.859197
# 18  {'bootstrap': True, 'criterion': 'squared_erro...           0.856588
# 29  {'bootstrap': True, 'criterion': 'squared_erro...           0.863246
# 15  {'bootstrap': True, 'criterion': 'squared_erro...           0.863021
# 47  {'bootstrap': True, 'criterion': 'squared_erro...           0.863021
# 34  {'bootstrap': True, 'criterion': 'squared_erro...           0.860222
# 2   {'bootstrap': True, 'criterion': 'squared_erro...           0.860222
# 35  {'bootstrap': True, 'criterion': 'squared_erro...           0.857994
# 3   {'bootstrap': True, 'criterion': 'squared_erro...           0.857994
# 30  {'bootstrap': True, 'criterion': 'squared_erro...           0.863132
# 17  {'bootstrap': True, 'criterion': 'squared_erro...           0.859850
# 13  {'bootstrap': True, 'criterion': 'squared_erro...           0.861208
# 45  {'bootstrap': True, 'criterion': 'squared_erro...           0.861208
# 28  {'bootstrap': True, 'criterion': 'squared_erro...           0.861772
# 14  {'bootstrap': True, 'criterion': 'squared_erro...           0.861222
# 46  {'bootstrap': True, 'criterion': 'squared_erro...           0.861222
# 16  {'bootstrap': True, 'criterion': 'squared_erro...           0.856581
# 44  {'bootstrap': True, 'criterion': 'squared_erro...           0.858941
# 12  {'bootstrap': True, 'criterion': 'squared_erro...           0.858941
# 27  {'bootstrap': True, 'criterion': 'squared_erro...           0.863546
# 1   {'bootstrap': True, 'criterion': 'squared_erro...           0.851177
# 26  {'bootstrap': True, 'criterion': 'squared_erro...           0.864103
# 33  {'bootstrap': True, 'criterion': 'squared_erro...           0.850867
# 11  {'bootstrap': True, 'criterion': 'squared_erro...           0.861079
# 43  {'bootstrap': True, 'criterion': 'squared_erro...           0.861079
# 0   {'bootstrap': True, 'criterion': 'squared_erro...           0.850987
# 32  {'bootstrap': True, 'criterion': 'squared_erro...           0.850295
# 10  {'bootstrap': True, 'criterion': 'squared_erro...           0.861402
# 42  {'bootstrap': True, 'criterion': 'squared_erro...           0.861402
# 25  {'bootstrap': True, 'criterion': 'squared_erro...           0.856657
# 24  {'bootstrap': True, 'criterion': 'squared_erro...           0.856040
# 41  {'bootstrap': True, 'criterion': 'squared_erro...           0.853283
# 9   {'bootstrap': True, 'criterion': 'squared_erro...           0.853375
# 8   {'bootstrap': True, 'criterion': 'squared_erro...           0.853035
# 40  {'bootstrap': True, 'criterion': 'squared_erro...           0.852739
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 23           0.837034           0.824889           0.849342
# 39           0.839737           0.818452           0.848957
# 7            0.839737           0.818452           0.848957
# 22           0.833323           0.817969           0.852857
# 21           0.838644           0.818492           0.847555
# 38           0.838706           0.814139           0.851226
# 6            0.838706           0.814139           0.851226
# 20           0.838557           0.812172           0.846875
# 4            0.837788           0.814434           0.842292
# 36           0.837788           0.814434           0.842292
# 5            0.835919           0.818473           0.845729
# 37           0.835919           0.818166           0.845729
# 31           0.836312           0.806753           0.845471
# 19           0.836369           0.814177           0.844673
# 18           0.836121           0.813278           0.845091
# 29           0.834743           0.804812           0.845869
# 15           0.835384           0.806243           0.843823
# 47           0.835384           0.806242           0.843823
# 34           0.840501           0.812490           0.835590
# 2            0.840501           0.812362           0.835590
# 35           0.838147           0.820272           0.838219
# 3            0.838147           0.820213           0.838219
# 30           0.830873           0.805439           0.845365
# 17           0.832549           0.813494           0.843568
# 13           0.832777           0.804636           0.843419
# 45           0.832777           0.804623           0.843419
# 28           0.828941           0.804712           0.845295
# 14           0.830033           0.805339           0.843839
# 46           0.830033           0.805339           0.843839
# 16           0.831115           0.813314           0.842091
# 44           0.827646           0.805186           0.842607
# 12           0.827646           0.805186           0.842607
# 27           0.832399           0.803353           0.826240
# 1            0.830581           0.806324           0.837058
# 26           0.826493           0.802251           0.825127
# 33           0.830732           0.806331           0.837297
# 11           0.830508           0.801190           0.822793
# 43           0.830508           0.801190           0.822793
# 0            0.829990           0.797353           0.836392
# 32           0.830168           0.797353           0.836392
# 10           0.824616           0.800912           0.822954
# 42           0.824616           0.800912           0.822954
# 25           0.825051           0.799272           0.820830
# 24           0.816491           0.797597           0.819317
# 41           0.817116           0.794489           0.813439
# 9            0.817048           0.794460           0.813304
# 8            0.809070           0.793078           0.812175
# 40           0.809025           0.793077           0.812476
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 23           0.781709         0.830408        0.026928                1
# 39           0.783423         0.830391        0.027354                2
# 7            0.783423         0.830360        0.027319                3
# 22           0.781902         0.829245        0.027926                4
# 21           0.781965         0.829184        0.027114                5
# 38           0.782986         0.829127        0.027572                6
# 6            0.782986         0.829062        0.027503                7
# 20           0.782776         0.828125        0.027580                8
# 4            0.783156         0.827914        0.026997                9
# 36           0.783156         0.827914        0.026997                9
# 5            0.779224         0.827769        0.027709               11
# 37           0.779224         0.827708        0.027730               12
# 31           0.783755         0.827417        0.028759               13
# 19           0.782613         0.827406        0.026723               14
# 18           0.783256         0.826867        0.026029               15
# 29           0.783256         0.826385        0.028753               16
# 15           0.783012         0.826297        0.028334               17
# 47           0.783012         0.826296        0.028334               18
# 34           0.781529         0.826066        0.026958               19
# 2            0.781529         0.826041        0.026971               20
# 35           0.775360         0.825999        0.027992               21
# 3            0.775360         0.825987        0.027994               22
# 30           0.784130         0.825788        0.028118               23
# 17           0.777334         0.825359        0.028355               24
# 13           0.782354         0.824879        0.028086               25
# 45           0.782354         0.824876        0.028088               26
# 28           0.783357         0.824815        0.028018               27
# 14           0.782360         0.824559        0.027914               28
# 46           0.782360         0.824559        0.027914               28
# 16           0.776292         0.823879        0.027675               30
# 44           0.781977         0.823272        0.027194               31
# 12           0.781977         0.823272        0.027194               31
# 27           0.775822         0.820272        0.029385               33
# 1            0.769824         0.818993        0.028546               34
# 26           0.776930         0.818981        0.028908               35
# 33           0.769251         0.818896        0.028717               36
# 11           0.773839         0.817882        0.029216               37
# 43           0.773834         0.817881        0.029218               38
# 0            0.774624         0.817869        0.027849               39
# 32           0.773965         0.817635        0.027907               40
# 10           0.773954         0.816767        0.028902               41
# 42           0.773954         0.816767        0.028902               41
# 25           0.767188         0.813800        0.029653               43
# 24           0.767159         0.811321        0.029083               44
# 41           0.766528         0.808971        0.028499               45
# 9            0.766640         0.808965        0.028489               46
# 8            0.765805         0.806633        0.028427               47
# 40           0.765573         0.806578        0.028409               48

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
#importing pickle to save the file
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
load_model=pickle.load(open("/content/RF_G.sav","rb"))

# %%
#this code is for getting input from user
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:61
# BMI:29.070
# Children:0
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[45785.82081106]
