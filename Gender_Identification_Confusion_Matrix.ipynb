# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshu-09/AISECT-AIML/blob/main/Gender_Identification_Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing pandas for data analaysis
import pandas as pd

# %%
#loading data and assigning it a variable name"dataset"
dataset=pd.read_csv("/content/gender_classification_v7.csv")

# %%
dataset
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
dataset
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
#splitting the value for independent and independent
x=dataset[["long_hair",	"forehead_width_cm",	"forehead_height_cm",	"nose_wide",	"nose_long",	"lips_thin",	"distance_nose_to_lip_long"]]
y=dataset[["gender"]]

# %%
#splitting the value 80% independent and 20% dependent
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
#importing the algorithm-here we choose decision tree
from sklearn.tree import DecisionTreeClassifier

# %%
cls=DecisionTreeClassifier()
cls.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=cls.predict(X_test)

# %%
##importing performance metrics since we use classification algorithm
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
precision = precision_score(y_test, y_pred,average=None,labels=["Male","Female"])
recall = recall_score(y_test, y_pred,average=None,labels=["Male","Female"])

# %%
##checking the accuracy
precision
# Out:
# array([0.95757576, 0.95059289])

# %%
recall
# Out:
# array([0.9498998 , 0.95816733])

# %%
import pickle

# %%
#saving the file under sav extension
filename="DecisionTreeclassifier.sav"

# %%
pickle.dump(cls,open(filename,"wb"))

# %%
#reading the code which we saved
load_model=pickle.load(open("/content/DecisionTreeclassifier.sav","rb"))

# %%
result=load_model.predict([[1,	11.8,	6.1,	1,	0,	1,	1	]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array(['Male'], dtype=object)
